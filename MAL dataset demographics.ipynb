# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\moham\Downloads\tweets-engagement-metrics.csv")

# %%
df.set_index('UserID')
# Out:
#                Unnamed: 0   Gender  LocationID      City            State  \
# UserID
# tw-1267804344           0  Unknown         1.0   Elbasan          Elbasan
# tw-27229880             1     Male         2.0    Tirana           Tirane
# tw-27229880             2     Male         2.0    Tirana           Tirane
# tw-27229880             3     Male         2.0    Tirana           Tirane
# tw-27229880             4     Male         2.0    Tirana           Tirane
# ...                   ...      ...         ...       ...              ...
# tw-8184962         102057     Male      6288.0    Harare  Harare Province
# tw-2510632527      102058  Unknown      6288.0    Harare  Harare Province
# tw-148753637       102059  Unknown      6288.0    Harare  Harare Province
# tw-448919812       102060   Unisex      6288.0    Harare  Harare Province
# tw-252561397       102061  Unknown      6289.0  Bulawayo         Bulawayo
#
#               StateCode   Country                TweetID  Hour  Day  \
# ...

# %%
pd.set_option('display.max.rows' , 234)

# %%
df
# Out:
#         Unnamed: 0         UserID   Gender  LocationID      City  \
# 0                0  tw-1267804344  Unknown         1.0   Elbasan
# 1                1    tw-27229880     Male         2.0    Tirana
# 2                2    tw-27229880     Male         2.0    Tirana
# 3                3    tw-27229880     Male         2.0    Tirana
# 4                4    tw-27229880     Male         2.0    Tirana
# ...            ...            ...      ...         ...       ...
# 102057      102057     tw-8184962     Male      6288.0    Harare
# 102058      102058  tw-2510632527  Unknown      6288.0    Harare
# 102059      102059   tw-148753637  Unknown      6288.0    Harare
# 102060      102060   tw-448919812   Unisex      6288.0    Harare
# 102061      102061   tw-252561397  Unknown      6289.0  Bulawayo
#
#                   State StateCode   Country                TweetID  Hour  Day  \
# 0               Elbasan        AL   Albania  tw-698155297102295041     7   12
# ...

# %%
df.drop_duplicates()
# Out:
#         Unnamed: 0         UserID   Gender  LocationID      City  \
# 0                0  tw-1267804344  Unknown         1.0   Elbasan
# 1                1    tw-27229880     Male         2.0    Tirana
# 2                2    tw-27229880     Male         2.0    Tirana
# 3                3    tw-27229880     Male         2.0    Tirana
# 4                4    tw-27229880     Male         2.0    Tirana
# ...            ...            ...      ...         ...       ...
# 102057      102057     tw-8184962     Male      6288.0    Harare
# 102058      102058  tw-2510632527  Unknown      6288.0    Harare
# 102059      102059   tw-148753637  Unknown      6288.0    Harare
# 102060      102060   tw-448919812   Unisex      6288.0    Harare
# 102061      102061   tw-252561397  Unknown      6289.0  Bulawayo
#
#                   State StateCode   Country                TweetID  Hour  Day  \
# 0               Elbasan        AL   Albania  tw-698155297102295041     7   12
# ...

# %%
Data_Frame_Klout = df.groupby('Country').sum(numeric_only = True).sort_values(by="Klout", ascending=False)

# %%
Data_Frame_Klout
# Out:
#                                     Unnamed: 0   LocationID    Hour     Day  \
# Country
# United States                       3898485234  199638373.0  629896  817880
# United Kingdom                       452815155   30839325.0   90814  156292
# India                                141943757    9247638.0   78150  113218
# Germany                               53306218    3838849.0   34213   56890
# France                                42141298    3002342.0   37738   58180
# Australia                              6563380     254106.0   39140   47940
# Spain                                 78192450    5763179.0   20401   35572
# Ireland                               38483568    2392730.0   12992   23550
# Japan                                 38446996    2449626.0   17215   21483
# Canada                                 8127380     597005.0   14758   19532
# Brazil                                 7201194     422206.0   17609   22810
# ...

# %%
df_weekday_traffic = df.groupby("Weekday").sum(numeric_only = True).sort_values(by=['Reach', 'Likes', 'Klout'], ascending= [False,False,False])
df_weekday_traffic
# Out:
#            Unnamed: 0  LocationID    Hour     Day  IsReshare        Reach  \
# Weekday
# Thursday    962470860  53173336.0  221828  329444       6646  200359283.0
# Tuesday     978699246  54171904.0  215856  269848       6668  172573340.0
# Wednesday   939185380  52421875.0  213893  292189       6703  161359812.0
# Monday      799055235  44343099.0  185735  253606       5478  133228791.0
# Friday      784393763  43329488.0  163034  229343       5347  118462343.0
# Saturday    385512404  21692242.0   82249  121380       2817   40434091.0
# Sunday      358958003  20337085.0   82560  126844       2551   33596480.0
#
#            RetweetCount   Likes     Klout    Sentiment
# Weekday
# Thursday       139680.0  3114.0  759076.0  6460.415230
# Tuesday        143249.0  2702.0  757555.0  7516.438992
# Wednesday      167734.0  2889.0  748158.0  6957.778812
# Monday         109546.0  2575.0  643351.0  6346.952863
# Friday         120936.0  2307.0  618047.0  6678.829139
# ...

# %%
peak_hours = df.groupby('Hour').mean(numeric_only = True).sort_values(by=['Reach', 'Likes', 'Klout'], ascending=[False,False, False])
peak_hours
# Out:
#         Unnamed: 0   LocationID        Day  IsReshare         Reach  \
# Hour
# 16    53048.771584  2905.964585  15.975272   0.371123  14629.759011
# 11    54954.227287  3002.589098  16.038572   0.329774  12170.019286
# 14    54484.342615  2956.545437  16.861900   0.366322  11678.807526
# 12    54536.873985  2990.678281  16.028078   0.354702  11483.405616
# 15    54272.540946  2972.113802  15.701845   0.367166  11277.038447
# 10    54897.637730  2987.368185  16.422542   0.360192  11139.278177
# 1     38383.838028  2322.885723  15.772087   0.404609  10297.075224
# 18    54855.023243  2973.377297  15.986216   0.394054   9547.795676
# 19    53321.434135  2916.406071  15.924112   0.376289   9418.160367
# 17    53401.064953  2905.713802  15.890167   0.374380   9167.604646
# 13    54362.392489  2959.261230  16.190538   0.368004   8965.648196
# 20    53755.433665  2937.657565  15.937681   0.398651   8355.719884
# 9     56096.893902  3055.666336  15.439431   0.329037   8144.883986
# ...

# %%
df.agg({'TweetID': ['sum', 'max'], 'text': 'mean'}).sort_values(by='TweetID', ascending=False)

# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\moham\Downloads\tweets-engagement-metrics.csv")
df
# Out:
#         Unnamed: 0         UserID   Gender  LocationID      City  \
# 0                0  tw-1267804344  Unknown         1.0   Elbasan
# 1                1    tw-27229880     Male         2.0    Tirana
# 2                2    tw-27229880     Male         2.0    Tirana
# 3                3    tw-27229880     Male         2.0    Tirana
# 4                4    tw-27229880     Male         2.0    Tirana
# ...            ...            ...      ...         ...       ...
# 102057      102057     tw-8184962     Male      6288.0    Harare
# 102058      102058  tw-2510632527  Unknown      6288.0    Harare
# 102059      102059   tw-148753637  Unknown      6288.0    Harare
# 102060      102060   tw-448919812   Unisex      6288.0    Harare
# 102061      102061   tw-252561397  Unknown      6289.0  Bulawayo
#
#                   State StateCode   Country                TweetID  Hour  Day  \
# 0               Elbasan        AL   Albania  tw-698155297102295041     7   12
# ...

# %%
df.drop_duplicates()
# Out:
#         Unnamed: 0         UserID   Gender  LocationID      City  \
# 0                0  tw-1267804344  Unknown         1.0   Elbasan
# 1                1    tw-27229880     Male         2.0    Tirana
# 2                2    tw-27229880     Male         2.0    Tirana
# 3                3    tw-27229880     Male         2.0    Tirana
# 4                4    tw-27229880     Male         2.0    Tirana
# ...            ...            ...      ...         ...       ...
# 102057      102057     tw-8184962     Male      6288.0    Harare
# 102058      102058  tw-2510632527  Unknown      6288.0    Harare
# 102059      102059   tw-148753637  Unknown      6288.0    Harare
# 102060      102060   tw-448919812   Unisex      6288.0    Harare
# 102061      102061   tw-252561397  Unknown      6289.0  Bulawayo
#
#                   State StateCode   Country                TweetID  Hour  Day  \
# 0               Elbasan        AL   Albania  tw-698155297102295041     7   12
# ...

# %% [markdown]
# df.groupby(['TweetId', 'text']).max(numeric_only = True).sort_values(by='TweetID', ascending = False)

# %%
df.groupby(['text','TweetID','Reach']).max(numeric_only = True).sort_values(by='TweetID', ascending=False)
# Out:
#                                                                                  Unnamed: 0  \
# text                                               TweetID               Reach
# Great turn out for the AWS Plant Sale and the F... tw-716352771209887744 2422.0       95135
# RT @goserverless: Serverless Offline: Emulate A... tw-716352501860196352 287.0        80845
# RT @awscloud: Test your iOS Android &amp; web a... tw-716351557516722176 122.0        21302
# I added a video to a @YouTube playlist https://... tw-716349615340199937 763.0        19345
# RT @iiManjula: Dekhana thoda dhirese darlingmen... tw-716349486742700032 1143.0       23577
# ...                                                                                     ...
# Amazon is hiring! #Sr. #International Tax Manag... tw-682714048199311366 953.0        58401
# Happy New Year to all those AWS instances of ours! tw-682713436967579648 2087.0       67901
# ...

# %%
df[['TweetID', 'text', 'RetweetCount']].sort_values(by='RetweetCount', ascending=False)
# Out:
#                       TweetID  \
# 98345   tw-700865627364392960
# 100722  tw-707929034768850944
# 100723  tw-707941144051654656
# 60084   tw-704537807935549441
# 59832   tw-695374760021090304
# ...                       ...
# 54508   tw-707365400112205824
# 54510   tw-707729014069268481
# 54511   tw-708044855025524738
# 54512   tw-708301483167588353
# 51031   tw-701836621688262657
#
#                                                      text  RetweetCount
# 98345   RT @Chargers: soo hungry need to find my wife ...       26127.0
# 100722  RT @2319guy: if I had this set of teeth I woul...       13195.0
# 100723  RT @LifeWithAlcohol: Spring break forecast htt...        2065.0
# 60084   Test your iOS Android &amp; web apps against r...         782.0
# 59832   Learn how to set up Parse Server on AWS using ...         637.0
# ...                                                   ...           ...
# 54508   How To Build Fault Tolerant Cross-Region #AWS ...           0.0
# ...

# %%
df['Hour'].apply(lambda x: pd.to_datetime(x))
# Out:
# 0        1970-01-01 00:00:00.000000007
# 1        1970-01-01 00:00:00.000000011
# 2        1970-01-01 00:00:00.000000006
# 3        1970-01-01 00:00:00.000000010
# 4        1970-01-01 00:00:00.000000009
#                       ...
# 102057   1970-01-01 00:00:00.000000010
# 102058   1970-01-01 00:00:00.000000005
# 102059   1970-01-01 00:00:00.000000000
# 102060   1970-01-01 00:00:00.000000008
# 102061   1970-01-01 00:00:00.000000012
# Name: Hour, Length: 102062, dtype: datetime64[ns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 102062 entries, 0 to 102061
# Data columns (total 20 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   Unnamed: 0    102062 non-null  int64
#  1   UserID        102062 non-null  object
#  2   Gender        102062 non-null  object
#  3   LocationID    102062 non-null  float64
#  4   City          99783 non-null   object
#  5   State         100165 non-null  object
#  6   StateCode     100336 non-null  object
#  7   Country       102062 non-null  object
#  8   TweetID       102062 non-null  object
#  9   Hour          102062 non-null  int64
#  10  Day           102062 non-null  int64
#  11  Weekday       102062 non-null  object
#  12  IsReshare     102062 non-null  bool
#  13  Reach         102062 non-null  float64
#  14  RetweetCount  102062 non-null  float64
#  15  Likes         102062 non-null  float64
#  16  Klout         102062 non-null  float64
# ...

# %%
df["Hour"]
# Out:
# 0          7
# 1         11
# 2          6
# 3         10
# 4          9
#           ..
# 102057    10
# 102058     5
# 102059     0
# 102060     8
# 102061    12
# Name: Hour, Length: 102062, dtype: int64

# %%
df["Hour"] = df["Hour"].apply(lambda x: str(x))

# %%
df["Hour"] = df['Hour'].apply(lambda x: x + ':' + '0' + '0')

# %%
df[["Gender", "Reach", "Hour"]].sort_values(by='Reach', ascending=False)
# Out:
#          Gender       Reach   Hour
# 53032      Male  10342452.0   1:00
# 53079      Male   8196371.0   0:00
# 67044   Unknown   6485485.0  20:00
# 67043   Unknown   6482073.0  10:00
# 67042   Unknown   6425442.0   2:00
# ...         ...         ...    ...
# 94970      Male         0.0  22:00
# 44761    Unisex         0.0   9:00
# 24307    Unisex         0.0  20:00
# 101049  Unknown         0.0  11:00
# 32652    Female         0.0   6:00
#
# [102062 rows x 3 columns]

# %%
df["Gender"].count()
# Out:
# 102062
